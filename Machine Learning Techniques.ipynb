# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv(r"C:\Users\saads\Downloads\Train single and multiple linear regression\retail_dataset.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           200 non-null    int64
#  1   Ad_Spending          200 non-null    float64
#  2   Discount_Rate        200 non-null    float64
#  3   Number_of_Employees  200 non-null    int64
#  4   Store_Size           200 non-null    float64
#  5   Online_Presence      200 non-null    float64
#  6   Monthly_Sales        200 non-null    float64
# dtypes: float64(5), int64(2)
# memory usage: 11.1 KB

# %%
df.describe()
# Out:
#        Unnamed: 0  Ad_Spending  Discount_Rate  Number_of_Employees  \
# count  200.000000   200.000000     200.000000           200.000000
# mean    99.500000    49.050490      11.115827            28.310000
# std     57.879185    30.321791       5.323761            13.169323
# min      0.000000     1.011323       1.007638             5.000000
# 25%     49.750000    20.997535       6.876025            16.750000
# 50%     99.500000    53.481058      11.377967            30.000000
# 75%    149.250000    74.990882      15.933132            39.000000
# max    199.000000    99.734962      19.884347            49.000000
#
#         Store_Size  Online_Presence  Monthly_Sales
# count   200.000000       200.000000     200.000000
# mean   2737.462756         4.967442      73.351599
# std    1271.101632         2.746048      10.495803
# min     514.007860         0.089391      50.955844
# 25%    1531.162611         2.764662      65.921828
# 50%    2778.400193         4.828815      73.114358
# ...

# %%
df
# Out:
#      Unnamed: 0  Ad_Spending  Discount_Rate  Number_of_Employees   Store_Size  \
# 0             0    42.285178      19.053346                   12  1119.482334
# 1             1    72.312125      11.576411                   33   548.999302
# 2             2     1.011323      18.396521                   24  3912.252172
# 3             3    30.930925      13.189758                   32  1939.787771
# 4             4    15.528833       8.410147                   48  4929.725526
# ..          ...          ...            ...                  ...          ...
# 195         195    93.265235      17.032968                   17   535.697943
# 196         196     2.381206       8.239306                   46  4952.030253
# 197         197    24.201847      15.247308                   40   849.715566
# 198         198    62.061057      10.711688                   30  1949.582811
# 199         199    94.952616      11.278084                   42  4757.685780
#
# ...

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df
# Out:
#      Ad_Spending  Discount_Rate  Number_of_Employees   Store_Size  \
# 0      42.285178      19.053346                   12  1119.482334
# 1      72.312125      11.576411                   33   548.999302
# 2       1.011323      18.396521                   24  3912.252172
# 3      30.930925      13.189758                   32  1939.787771
# 4      15.528833       8.410147                   48  4929.725526
# ..           ...            ...                  ...          ...
# 195    93.265235      17.032968                   17   535.697943
# 196     2.381206       8.239306                   46  4952.030253
# 197    24.201847      15.247308                   40   849.715566
# 198    62.061057      10.711688                   30  1949.582811
# 199    94.952616      11.278084                   42  4757.685780
#
#      Online_Presence  Monthly_Sales
# 0           0.089391      66.614076
# 1           8.227300      74.000726
# 2           8.612116      57.039761
# ...

# %%
df.corr()
# Out:
#                      Ad_Spending  Discount_Rate  Number_of_Employees  \
# Ad_Spending             1.000000      -0.068443             0.015977
# Discount_Rate          -0.068443       1.000000             0.007447
# Number_of_Employees     0.015977       0.007447             1.000000
# Store_Size             -0.029298      -0.029664            -0.034443
# Online_Presence         0.031240       0.127355            -0.053888
# Monthly_Sales           0.864063      -0.105338             0.087586
#
#                      Store_Size  Online_Presence  Monthly_Sales
# Ad_Spending           -0.029298         0.031240       0.864063
# Discount_Rate         -0.029664         0.127355      -0.105338
# Number_of_Employees   -0.034443        -0.053888       0.087586
# Store_Size             1.000000        -0.098878       0.149820
# Online_Presence       -0.098878         1.000000       0.137374
# Monthly_Sales          0.149820         0.137374       1.000000

# %%
import seaborn as sb

# %%
sb.pairplot(df)

# %%
sb.jointplot(x='Ad_Spending', y='Monthly_Sales', data = df)

# %%
sb.lmplot(x='Ad_Spending', y='Monthly_Sales', data = df)

# %%
y = df['Monthly_Sales']

# %%
X = df[['Ad_Spending']]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)

# %%
X_train.shape
# Out:
# (160, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression(fit_intercept = True)

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print('Linear Model Coefficient (m): ', model.coef_)
print('Linear Model Coefficient (b): ', model.intercept_)
# Out:
# Linear Model Coefficient (m):  [0.30297741]
# Linear Model Coefficient (b):  58.37242610853947

# %%
y_predict = model.predict( X_test)
y_predict
# Out:
# array([64.80790046, 85.54729903, 76.35148391, 87.77092398, 83.93192126,
#        64.6174109 , 63.0773118 , 58.7614983 , 88.32871157, 66.24385463,
#        79.44145686, 61.74490054, 75.8959255 , 61.44507786, 59.84684252,
#        59.14995796, 82.69019143, 73.26321025, 80.28136657, 75.4639822 ,
#        81.28774173, 76.86211251, 74.66757031, 59.22395608, 59.52444994,
#        87.61555285, 59.46159588, 85.1699611 , 65.70503894, 70.07764821,
#        85.92670078, 60.83425504, 60.65506311, 68.07648772, 62.85296466,
#        66.48349342, 69.10655834, 79.2668367 , 76.26898342, 85.77205887])

# %%
data = [4]
data1 = pd.DataFrame(data)
model.predict(data1)
# Out:
# C:\Users\saads\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([59.58433576])

# %%
print(model.coef_)
print(model.intercept_)
# Out:
# [0.30297741]
# 58.37242610853947

# %%
# y = mx+b

# %%
from sklearn import metrics

# %%
#print MAE
print('MAE: ', metrics.mean_absolute_error(y_test, y_predict))

#print MSE
print('MSE: ',metrics.mean_squared_error(y_test, y_predict))

#print RMSE
print('RMSE: ',np.sqrt(metrics.mean_squared_error(y_test, y_predict)))

#print R2
print('R2: ',metrics.r2_score(y_test,y_predict))
# Out:
# MAE:  4.090952423807313
# MSE:  22.587100754406425
# RMSE:  4.752588847607841
# R2:  0.7975667779589071

# %%
from sklearn import linear_model

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['Ad_Spending','Number_of_Employees','Online_Presence']],df['Monthly_Sales'])
# Out:
# LinearRegression()

# %%
reg.predict([[2,9,6]])
# Out:
# C:\Users\saads\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([58.57971812])

# %%
reg.predict([[12,10,10]])
# Out:
# C:\Users\saads\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([63.37343959])

# %%
reg.coef_
# Out:
# array([0.29740832, 0.0637973 , 0.43896024])

# %%
reg.intercept_
# Out:
# 54.77696428372495

# %%
0.29740832+ 0.0637973 + 0.43896024 * 54.77696428372495
# Out:
# 24.406115008455334

# %%
#print R2
print('R2: ',metrics.r2_score(y_test,y_predict))
# Out:
# R2:  0.7975667779589071

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_regressor = PolynomialFeatures(degree=2)
# import a class and instantiate an object from that class

# %%
# Transform the matrix of features X into a multi array of features X_Columns 
# which contains the original features and their associated polynomial terms 
X_columns = poly_regressor.fit_transform(X_train)

# %%
regressor = LinearRegression()
regressor.fit(X_columns, y_train)
# Out:
# LinearRegression()

# %%
print('Model Coefficients:',regressor.coef_)
# Out:
# Model Coefficients: [ 0.          0.36576413 -0.00063546]

# %%
X_train.shape
# Out:
# (160, 1)

# %%
y_predict = regressor.predict(poly_regressor.fit_transform(X_train))

# %%
y_predict.shape
# Out:
# (160,)

# %%
print(X_columns)
# Out:
# [[1.00000000e+00 6.93987948e+01 4.81619272e+03]
#  [1.00000000e+00 1.73700655e+01 3.01719176e+02]
#  [1.00000000e+00 2.72270362e+01 7.41311501e+02]
#  [1.00000000e+00 5.94539244e+00 3.53476912e+01]
#  [1.00000000e+00 4.02799799e+01 1.62247678e+03]
#  [1.00000000e+00 1.55261289e+01 2.41060679e+02]
#  [1.00000000e+00 5.43442754e+01 2.95330027e+03]
#  [1.00000000e+00 5.83947767e+01 3.40994995e+03]
#  [1.00000000e+00 3.71137173e+00 1.37742801e+01]
#  [1.00000000e+00 7.53014798e+00 5.67031286e+01]
#  [1.00000000e+00 8.77625261e+01 7.70226098e+03]
#  [1.00000000e+00 6.20973464e+01 3.85608044e+03]
#  [1.00000000e+00 2.44656710e+01 5.98569060e+02]
#  [1.00000000e+00 2.72891193e+01 7.44696031e+02]
#  [1.00000000e+00 6.20610573e+01 3.85157484e+03]
#  [1.00000000e+00 8.09034144e+01 6.54536246e+03]
#  [1.00000000e+00 7.15859091e+01 5.12454238e+03]
#  [1.00000000e+00 8.79361078e+01 7.73275906e+03]
#  [1.00000000e+00 1.38728286e+01 1.92455374e+02]
#  [1.00000000e+00 2.19511835e+01 4.81854456e+02]
# ...
